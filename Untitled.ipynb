# %%
BASE_URL = "http://test.tvmucho.com"
BASE_URL_2 = "https://tvmucho.com/"
# BASE_URL = "http://flixon.tvmucho.com"

# %%
import string
import random

"""Class to generate random data, which can be used in tests"""


class Randomizer(object):
    def number(size=10, chars=string.digits):
        return ''.join(random.choice(chars) for _ in range(size))

    def word(size=10, chars=string.ascii_uppercase + string.ascii_lowercase):
        return ''.join(random.choice(chars) for _ in range(size))

    def text(min_size=50, max_size=100, chars=string.ascii_uppercase + string.ascii_lowercase + string.digits + string.punctuation + " "):
        return ''.join(random.choice(chars) for _ in range(random.randint(min_size, max_size)))

    # Same to text but with "\n" (new line) char.
    def page_of_text(min_size=50, max_size=100, chars=string.ascii_uppercase + string.ascii_lowercase + string.digits + string.punctuation + " " + "\n"):
        return ''.join(random.choice(chars) for _ in range(random.randint(min_size, max_size)))

    def email(base_email='', base_domain ='gmail.com'):
        email = base_email
        email += ''.join(random.choice(string.ascii_lowercase + string.digits) for _ in range(6))
        email += '@'
        email += base_domain
        return email

    def password(size=10, chars=string.ascii_uppercase + string.ascii_lowercase + string.digits + string.punctuation):
        return ''.join(random.choice(chars) for _ in range(size))

# %%
from selene.api import *

class OneHourViewFlow(object):

    def __init__(self):

        # /registration-1hour

        # 1st screen
        self.continue_watching_popup_title = s(by.partial_text("Continue watching?"))
        self.sign_in_button = s(by.text("Sign In"))
        self.log_in_with_facebook = s(by.text("Log in with Facebook"))
        self.log_in_with_google = s(by.text("Log in with Google"))
        self.log_in_with_email_button = s("#content > div.main-content > div.form.first > button.goto")

        # /watch-tv/activate
        self.oops_popup_title = s(by.text("Oops..."))
        self.renew_button = s("#renew")
        self.retry_button = s("#retry")
        self.get_help_button = s(by.text("Get Help"))
        self.sign_up_now_button = s(by.text("Sign up now"))
        self.email = s(by.partial_link_text("support@tvmucho.com"))

        # 1 Hour A Day For Free popup
        self.title = s(by.partial_text("1 hour a day for Free!"))
        self.name_field = s("#content > div.main-content > div.form.sign-up > input.name")
        self.email_field = s("#content > div.main-content > div.form.sign-up > input.email.keypress-hook")
        self.continue_button = s(".hook.continue")

        # Congratulations popup
        self.congratulations_title = s(by.text("Congratulations!"))
        self.congratulations_start_watching_online_button = s("#content > div.main-content > div.form.congratulations > a")
        self.help_email_button = s(by.partial_link_text("support@tvmucho.com"))


        # /watch-tv screen

        # personalvideo_recording_popup
        self.personalvideo_recording_popup_title = s("#modal1")
        self.personalvideo_recording_popup_title_text = s(by.text("Personal Video Recording"))
        self.no_button_on_video_recording_popup = s("#cancel1")
        # hooray popup
        self.yes_button_on_video_recording_popup = s("#confirm1")
        self.hooray_popup = s("#modal2")
        self.ok_button_on_hooray_popup = s("#confirm2")

        self.first_channel_in_the_scroller = s(by.xpath("//*[@id=='channels']/div[4]/div[1]/button[1]"))
        self.player_playstop_button = s("#playstop")

        # Registration Modal
        self.registration_modal = s("#registration-modal")
        self.registration_modal_signup_with_email_button = s("#registration-modal > button.email.login.button")
        self.yourname_field = s("#email-modal > div:nth-child(4) > input")
        self.youremail_field = s("#email-modal > div:nth-child(5) > input")
        self.another_continue_button = s("#email-modal > div:nth-child(7) > button > span.text")
        self.congratulations_modal_continue_button = s("#congratulations-modal > button.button")

        # Activation popup
        self.activation_popup = s("#activatewindow")
        self.renew_button = s("#signupbox > a")

        # Initial Continue Watching popup
        self.continue_watching_popup = s("#content > div.main-content > div.form.first")

# %%
import selenium
import pytest
from selenium import webdriver
from selene.api import *
from allure_commons._allure import attach
from allure_commons.types import AttachmentType

import os
from pathlib import Path
import shutil
import subprocess
import time



config.browser_name = 'chrome'

# %%
from selene.browser import driver
browser.open_url("www.google.com/")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-23-5f2355fc8823> in <module>
#       1 from selene.browser import driver
# ----> 2 browser.open_url("www.google.com/")
#
# c:\users\asher\appdata\local\programs\python\python37-32\lib\site-packages\selene\browser.py in open_url(absolute_or_relative_url)
#      53     # todo: refactor next line when app_host is removed
#      54     base_url = selene.config.app_host if selene.config.app_host else selene.config.base_url
# ---> 55     driver().get(base_url + absolute_or_relative_url)
#      56
#      57
#
# c:\users\asher\appdata\local\programs\python\python37-32\lib\site-packages\selene\browser.py in driver()
#      33 def driver():
#      34     # type: () -> WebDriver
# ---> 35     return selene.factory.ensure_driver_started(selene.config.browser_name)
#      36
#      37
#
# c:\users\asher\appdata\local\programs\python\python37-32\lib\site-packages\selene\factory.py in ensure_driver_started(name)
#      58         return get_shared_driver()
#      59
# ---> 60     return _start_driver(name)
#      61
#      62
#
# c:\users\asher\appdata\local\programs\python\python37-32\lib\site-packages\selene\factory.py in _start_driver(name)
#      90 def _start_driver(name):
#      91     kill_all_started_drivers()
# ---> 92     driver = __get_driver(name)
#      93     set_shared_driver(driver)
#      94     if not config.hold_browser_open:
#
# c:\users\asher\appdata\local\programs\python\python37-32\lib\site-packages\selene\factory.py in __get_driver(name)
#      83 def __get_driver(name):
#      84     if name == BrowserName.CHROME:
# ---> 85         return __start_chrome()
#      86     else:
#      87         return __start_firefox(name)
#
# c:\users\asher\appdata\local\programs\python\python37-32\lib\site-packages\selene\factory.py in __start_chrome()
#      65     if config.start_maximized:
#      66         options.add_argument("--start-maximized")
# ---> 67     return webdriver.Chrome(executable_path=ChromeDriverManager().install(),
#      68                             chrome_options=options,
#      69                             desired_capabilities=config.desired_capabilities)
#
# c:\users\asher\appdata\local\programs\python\python37-32\lib\site-packages\webdriver_manager\chrome.py in install(self, path)
#      17     def install(self, path=None):
#      18         # type: () -> str
# ---> 19         bin_file = self._file_manager.download_driver(self.driver, path)
#      20         os.chmod(bin_file.path, 0o755)
#      21         return bin_file.path
#
# c:\users\asher\appdata\local\programs\python\python37-32\lib\site-packages\webdriver_manager\cache.py in download_driver(self, driver, path)
#      68         if path is not None:
#      69             path = os.path.abspath(path)
# ---> 70         cached_binary = self.get_cached_binary(driver, path)
#      71         if cached_binary:
#      72             return cached_binary
#
# c:\users\asher\appdata\local\programs\python\python37-32\lib\site-packages\webdriver_manager\cache.py in get_cached_binary(self, driver, path)
#      38         version = driver.get_version()
#      39         os_type = driver.os_type
# ---> 40         console("")
#      41         console(
#      42             "Checking for {} {}:{} in cache".format(
#
# c:\users\asher\appdata\local\programs\python\python37-32\lib\site-packages\webdriver_manager\utils.py in console(text, bold)
#      42
#      43 def console(text, bold=False):
# ---> 44     print(crayons.yellow(text, bold=bold))
#
# c:\users\asher\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     406                     self.flush()
#     407             else:
# --> 408                 self._schedule_flush()
#     409
#     410     def writelines(self, sequence):
#
# c:\users\asher\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel\iostream.py in _schedule_flush(self)
#     330         def _schedule_in_thread():
#     331             self._io_loop.call_later(self.flush_interval, self._flush)
# --> 332         self.pub_thread.schedule(_schedule_in_thread)
#     333
#     334     def flush(self):
#
# c:\users\asher\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     203             self._event_pipe.send(b'')
#     204         else:
# --> 205             f()
#     206
#     207     def send_multipart(self, *args, **kwargs):
#
# c:\users\asher\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel\iostream.py in _schedule_in_thread()
#     329         # add_timeout has to be handed to the io thread via event pipe
#     330         def _schedule_in_thread():
# --> 331             self._io_loop.call_later(self.flush_interval, self._flush)
#     332         self.pub_thread.schedule(_schedule_in_thread)
#     333
#
# c:\users\asher\appdata\local\programs\python\python37-32\lib\site-packages\tornado\ioloop.py in call_later(self, delay, callback, *args, **kwargs)
#     636         .. versionadded:: 4.0
#     637         """
# --> 638         return self.call_at(self.time() + delay, callback, *args, **kwargs)
#     639
#     640     def call_at(self, when, callback, *args, **kwargs):
#
# c:\users\asher\appdata\local\programs\python\python37-32\lib\site-packages\tornado\platform\asyncio.py in call_at(self, when, callback, *args, **kwargs)
#     143         return self.asyncio_loop.call_later(
#     144             max(0, when - self.time()), self._run_callback,
# --> 145             functools.partial(stack_context.wrap(callback), *args, **kwargs))
#     146
#     147     def remove_timeout(self, timeout):
#
# c:\users\asher\appdata\local\programs\python\python37-32\lib\asyncio\base_events.py in call_later(self, delay, callback, context, *args)
#     639         """
#     640         timer = self.call_at(self.time() + delay, callback, *args,
# --> 641                              context=context)
#     642         if timer._source_traceback:
#     643             del timer._source_traceback[-1]
#
# c:\users\asher\appdata\local\programs\python\python37-32\lib\asyncio\base_events.py in call_at(self, when, callback, context, *args)
#     649         Absolute time corresponds to the event loop's time() method.
#     650         """
# --> 651         self._check_closed()
#     652         if self._debug:
#     653             self._check_thread()
#
# c:\users\asher\appdata\local\programs\python\python37-32\lib\asyncio\base_events.py in _check_closed(self)
#     459     def _check_closed(self):
#     460         if self._closed:
# --> 461             raise RuntimeError('Event loop is closed')
#     462
#     463     def _asyncgen_finalizer_hook(self, agen):
#
# RuntimeError: Event loop is closed
